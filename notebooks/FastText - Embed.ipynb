# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import ast

# %%
def convert(df):
    df = df.map({
        'negative': 0,
        'neutral': 1,
        'positive': 2
    })
    return df

# %%
df_train = pd.read_csv('/kaggle/input/vietnamese-synthetic-with-embedding/synthetic_train_ver2.csv')
df_test = pd.read_csv('/kaggle/input/vietnamese-synthetic-with-embedding/synthetic_val_ver2.csv')

df_train['sentiment'] = convert(df_train['sentiment'])
df_test['sentiment'] = convert(df_test['sentiment'])

# %%
df_train
# Out:
#                                                sentence  sentiment  \
# 0     Đội ngũ bảo trì quá thưa thớt dẫn đến không đả...          0
# 1     The university's musical and artistic faciliti...          1
# 2     Phương pháp giảng dạy phù hợp với các đối tượn...          1
# 3     Chương trình học giúp tôi trở thành một chuyên...          2
# 4     Tôi nghĩ rằng chương trình đào tạo có thể có t...          1
# ...                                                 ...        ...
# 8139  Hệ thống an ninh trong trường rất tốt và đảm b...          1
# 8140    Cô giáo đã giúp tôi hiểu rõ hơn về môn học này.          1
# 8141  Anh/chị đã trở thành một người bạn đồng hành v...          2
# 8142  Chương trình học phù hợp với nhu cầu của các n...          1
# 8143  Tôi cần chuyển sang học tại đại học khác để đá...          0
#
#            topic                                          embedding
# 0       facility  [-3.51069006e-03 -3.29673178e-02  8.83009806e-...
# 1       facility  [-1.31886899e-02  4.85030487e-02 -6.98061660e-...
# 2     curriculum  [-1.84284635e-02 -2.80237105e-02  5.56251481e-...
# 3     curriculum  [-0.01680681 -0.03022579  0.05584624  0.009929...
# 4     curriculum  [-3.60421874e-02 -1.76330674e-02  1.00807019e-...
# ...          ...                                                ...
# 8139    facility  [-2.24258061e-02 -2.51169293e-03  7.40335509e-...
# 8140      others  [-4.35926951e-02 -3.15630995e-02  8.76308084e-...
# 8141      others  [-1.47961583e-02 -3.03727612e-02  1.72781870e-...
# 8142  curriculum  [-2.41561532e-02 -3.50480229e-02  4.66375500e-...
# 8143  curriculum  [-1.4038659e-02 -3.2047804e-02  4.3705758e-02 ...
#
# [8144 rows x 4 columns]

# %%
def parse_embedding_string(s):
    # Bỏ dấu ngoặc vuông và split theo khoảng trắng
    return np.array([float(x) for x in s.strip("[]").split()])

# Áp dụng vào cột
X_train = np.vstack(df_train['embedding'].apply(parse_embedding_string))
X_test = np.vstack(df_test['embedding'].apply(parse_embedding_string))

y_train = df_train['sentiment']
y_test = df_test['sentiment']

# %%
X_train.shape
# Out:
# (8144, 300)

# %%
def plot_cm(model, y_test, y_pred, model_name):
    cm = confusion_matrix(y_test, y_pred)

    labels = model.classes_
    plt.figure(figsize=(8, 6))
    sns.heatmap(cm, annot=True, fmt='d', cmap='Greens',
                xticklabels=labels, yticklabels=labels)
    plt.xlabel('Predicted')
    plt.ylabel('Actual')
    plt.title(f'Confusion Matrix - {model_name}')
    plt.show()

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report

def train_rf(X_train, X_test, y_train, y_test):
    model = RandomForestClassifier(n_estimators=100, random_state=42)
    model.fit(X_train, y_train)

    y_pred = model.predict(X_test)

    print("\nClassification Report:\n", classification_report(y_test, y_pred))

    plot_cm(model, y_test, y_pred, 'RandomForestClassifier')
    return model

# %%
rf_model = train_rf(X_train, X_test, y_train, y_test)
# Out:
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.84      0.89      0.86       686
#            1       0.71      0.62      0.67       670
#            2       0.70      0.74      0.72       680
#
#     accuracy                           0.75      2036
#    macro avg       0.75      0.75      0.75      2036
# weighted avg       0.75      0.75      0.75      2036

# %%
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report
import seaborn as sns
import matplotlib.pyplot as plt

def train_svm(X_train, X_test, y_train, y_test):
    model = SVC(kernel='linear', probability=True, random_state=42)  # Có thể đổi kernel
    model.fit(X_train, y_train)

    y_pred = model.predict(X_test)

    print("\nClassification Report:\n", classification_report(y_test, y_pred))

    plot_cm(model, y_test, y_pred, 'SVM')
    return model

# %%
svm_model = train_svm(X_train, X_test, y_train, y_test)
# Out:
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.89      0.88      0.88       686
#            1       0.71      0.64      0.67       670
#            2       0.70      0.78      0.74       680
#
#     accuracy                           0.77      2036
#    macro avg       0.77      0.77      0.76      2036
# weighted avg       0.77      0.77      0.77      2036

# %%
from xgboost import XGBClassifier
from sklearn.metrics import classification_report, confusion_matrix
import seaborn as sns
import matplotlib.pyplot as plt

def train_xgboost(X_train, X_test, y_train, y_test):
    num_classes = len(set(y_train))  # Số lớp

    model = XGBClassifier(
        objective='multi:softprob',
        num_class=num_classes,
        use_label_encoder=False,
        eval_metric='mlogloss',
        random_state=42
    )

    model.fit(X_train, y_train)

    y_pred = model.predict(X_test)

    print("\nClassification Report:\n", classification_report(y_test, y_pred))
    
    plot_cm(model, y_test, y_pred, 'XGBoost')
    return model

# %%
xgb_model = train_xgboost(X_train, X_test, y_train, y_test)
# Out:
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.90      0.90      0.90       686
#            1       0.71      0.71      0.71       670
#            2       0.73      0.74      0.74       680
#
#     accuracy                           0.78      2036
#    macro avg       0.78      0.78      0.78      2036
# weighted avg       0.78      0.78      0.78      2036

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.optimizers import Adam
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report
import matplotlib.pyplot as plt
import seaborn as sns

def train_nn(X_train, X_test, y_train, y_test, num_classes):
    # Xây dựng mô hình
    model = Sequential()
    model.add(Dense(256, activation='relu', input_shape=(X_train.shape[1],)))
    model.add(Dense(64, activation='relu'))
    model.add(Dense(num_classes, activation='softmax'))  # softmax cho multi-class classification

    # Compile mô hình
    model.compile(optimizer=Adam(learning_rate=0.001),
                  loss='sparse_categorical_crossentropy',  # Nếu y là số nguyên (0,1,2..)
                  metrics=['accuracy'])

    # Huấn luyện mô hình
    history = model.fit(X_train, y_train, epochs=20, batch_size=16, validation_data=(X_test, y_test), verbose=1)

    # Dự đoán
    y_pred = model.predict(X_test)
    y_pred_classes = y_pred.argmax(axis=1)

    # Đánh giá
    print("Accuracy:", accuracy_score(y_test, y_pred_classes))
    print("\nClassification Report:\n", classification_report(y_test, y_pred_classes))

    # Confusion Matrix
    cm = confusion_matrix(y_test, y_pred_classes)
    labels = list(range(num_classes))

    plt.figure(figsize=(8, 6))
    sns.heatmap(cm, annot=True, fmt='d', cmap='Greens',
                xticklabels=labels, yticklabels=labels)
    plt.xlabel('Predicted')
    plt.ylabel('Actual')
    plt.title('Confusion Matrix - Neural Network')
    plt.show()

    return model
# Out:
# 2025-04-30 10:28:45.639695: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1746008925.889165      31 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1746008925.958875      31 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered

# %%
NN_model = train_nn(X_train, X_test, y_train, y_test, len(y_train.unique()))
# Out:
# Epoch 1/20
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 509/509 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.6079 - loss: 0.8303 - val_accuracy: 0.7539 - val_loss: 0.5556
# Epoch 2/20
# 509/509 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.7328 - loss: 0.5734 - val_accuracy: 0.7642 - val_loss: 0.5293
# Epoch 3/20
# 509/509 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.7658 - loss: 0.5129 - val_accuracy: 0.7750 - val_loss: 0.5059
# Epoch 4/20
# 509/509 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.7821 - loss: 0.4915 - val_accuracy: 0.7824 - val_loss: 0.4935
# Epoch 5/20
# 509/509 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.7824 - loss: 0.4808 - val_accuracy: 0.7888 - val_loss: 0.4789
# Epoch 6/20
# 509/509 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.7885 - loss: 0.4626 - val_accuracy: 0.7873 - val_loss: 0.4987
# Epoch 7/20
# 509/509 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8061 - loss: 0.4408 - val_accuracy: 0.7873 - val_loss: 0.4694
# Epoch 8/20
# 509/509 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.7987 - loss: 0.4417 - val_accuracy: 0.7824 - val_loss: 0.4937
# Epoch 9/20
# 509/509 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8135 - loss: 0.4125 - val_accuracy: 0.7859 - val_loss: 0.4781
# Epoch 10/20
# 509/509 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8200 - loss: 0.4090 - val_accuracy: 0.7868 - val_loss: 0.4669
# Epoch 11/20
# 509/509 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8275 - loss: 0.3972 - val_accuracy: 0.8006 - val_loss: 0.4591
# Epoch 12/20
# 509/509 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8238 - loss: 0.3812 - val_accuracy: 0.7790 - val_loss: 0.5010
# Epoch 13/20
# 509/509 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8389 - loss: 0.3649 - val_accuracy: 0.7819 - val_loss: 0.4912
# Epoch 14/20
# 509/509 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8486 - loss: 0.3471 - val_accuracy: 0.7996 - val_loss: 0.4715
# Epoch 15/20
# 509/509 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8479 - loss: 0.3452 - val_accuracy: 0.7932 - val_loss: 0.4681
# Epoch 16/20
# 509/509 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8489 - loss: 0.3336 - val_accuracy: 0.7913 - val_loss: 0.4640
# Epoch 17/20
# 509/509 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8518 - loss: 0.3318 - val_accuracy: 0.8099 - val_loss: 0.4575
# Epoch 18/20
# 509/509 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.8526 - loss: 0.3266 - val_accuracy: 0.8050 - val_loss: 0.4702
# Epoch 19/20
# 509/509 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.8647 - loss: 0.3006 - val_accuracy: 0.7986 - val_loss: 0.4663
# Epoch 20/20
# 509/509 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.8771 - loss: 0.2841 - val_accuracy: 0.8070 - val_loss: 0.4729
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# Accuracy: 0.8069744597249509
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.93      0.91      0.92       686
#            1       0.74      0.73      0.73       670
#            2       0.75      0.78      0.76       680
#
#     accuracy                           0.81      2036
#    macro avg       0.81      0.81      0.81      2036
# weighted avg       0.81      0.81      0.81      2036
